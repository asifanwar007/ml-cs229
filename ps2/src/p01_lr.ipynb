# %%
# Important note: you do not have to modify this file for your homework.
# %timeit

import util
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def calc_grad(X, Y, theta):
    """Compute the gradient of the loss with respect to theta."""
    m, n = X.shape

    margins = Y * X.dot(theta)
    probs = 1. / (1 + np.exp(margins))
    grad = -(1./m) * (X.T.dot(probs * Y))

    return grad

# %%
def logistic_regression(X, Y):
    """Train a logistic regression model."""
    m, n = X.shape
    theta = np.zeros(n)
    learning_rate =30
    print(learning_rate)
    i = 0
    while True:
        i += 1
        prev_theta = theta
        grad = calc_grad(X, Y, theta)
#         print(grad)
        new_theta = - (X*grad).sum(axis=0)
#         print(new_theta.sum(axis=0))
#         print(new_theta)
        theta = theta - learning_rate * new_theta
        if i % 100000 == 0:
            print('Finished %d iterations' % i)
            print(np.linalg.norm(prev_theta - theta))
            print(theta)
            util.plot(X, Y, theta, "p0111.jpeg")
        if np.linalg.norm(prev_theta - theta) < 1e-15:
            print('Converged in %d iterations' % i)
            break
    return theta

# %%
print('\n==== Training model on data set B ====')
Xb, Yb = util.load_csv('../data/ds1_b.csv', add_intercept=True)
# lb_view.map(logistic_regression, Xb, Yb, block=True)
# lb_view(logistic_regression(Xb, Yb), block=True)\
Xa = np.log(Xb)
theta=logistic_regression(Xb, Yb)
print(theta)
# Out:
# ==== Training model on data set B ====
# 30
# /home/asif/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in exp
# Finished 100000 iterations
# 1830.5063090456283
# [-1.64998500e+08 -5.85216312e+07 -5.34571367e+07]
# Finished 200000 iterations
# 1830.5063090480103
# [-3.29998500e+08 -1.17043657e+08 -1.06914653e+08]
# Finished 300000 iterations
# 1830.5063090480103
# [-4.94998500e+08 -1.75565682e+08 -1.60372168e+08]
# Finished 400000 iterations
# 1830.5063090480103
# [-6.59998500e+08 -2.34087708e+08 -2.13829684e+08]
# Finished 500000 iterations
# 1830.5063090384824
# [-8.24998500e+08 -2.92609733e+08 -2.67287200e+08]
# Finished 600000 iterations
# 1830.506309029779
# [-9.89998500e+08 -3.51131759e+08 -3.20744716e+08]
# Finished 700000 iterations
# 1830.506309029779
# [-1.15499850e+09 -4.09653785e+08 -3.74202232e+08]
# Finished 800000 iterations
# 1830.506309029779
# [-1.31999850e+09 -4.68175810e+08 -4.27659747e+08]
# Finished 900000 iterations
# 1830.506309029779
# [-1.48499850e+09 -5.26697836e+08 -4.81117263e+08]
# Finished 1000000 iterations
# 1830.506309029779
# [-1.64999850e+09 -5.85219861e+08 -5.34574779e+08]
# Finished 1100000 iterations
# 1830.506309029779
# [-1.81499850e+09 -6.43741887e+08 -5.88032295e+08]
# Finished 1200000 iterations
# 1830.506309029779
# [-1.97999850e+09 -7.02263912e+08 -6.41489811e+08]
# Finished 1300000 iterations
# 1830.506309029779
# [-2.14499850e+09 -7.60785938e+08 -6.94947326e+08]
# Finished 1400000 iterations
# 1830.506309029779
# [-2.30999850e+09 -8.19307964e+08 -7.48404842e+08]
# Finished 1500000 iterations
# 1830.506309029779
# [-2.47499850e+09 -8.77829989e+08 -8.01862358e+08]
# Finished 1600000 iterations
# 1830.506309029779
# [-2.63999850e+09 -9.36352015e+08 -8.55319874e+08]
# Finished 1700000 iterations
# 1830.506309029779
# [-2.8049985e+09 -9.9487404e+08 -9.0877739e+08]
# Finished 1800000 iterations
# 1830.506309029779
# [-2.96999850e+09 -1.05339607e+09 -9.62234906e+08]
# Finished 1900000 iterations
# 1830.5063090678907
# [-3.13499850e+09 -1.11191809e+09 -1.01569242e+09]
# Finished 2000000 iterations
# 1830.5063090678907
# [-3.29999850e+09 -1.17044012e+09 -1.06914994e+09]
# Finished 2100000 iterations
# 1830.5063090678907
# [-3.46499850e+09 -1.22896214e+09 -1.12260745e+09]
# /home/asif/Desktop/ml/ps2/src/util.py:90: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# Finished 2200000 iterations
# 1830.5063090678907
# [-3.62999850e+09 -1.28748417e+09 -1.17606497e+09]
# /home/asif/Desktop/ml/ps2/src/util.py:90: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# Finished 2300000 iterations
# 1830.5063090678907
# [-3.79499850e+09 -1.34600619e+09 -1.22952248e+09]
# /home/asif/Desktop/ml/ps2/src/util.py:90: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# Finished 2400000 iterations
# 1830.5063090678907
# [-3.95999850e+09 -1.40452822e+09 -1.28298000e+09]
# /home/asif/Desktop/ml/ps2/src/util.py:90: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-0903b7fdbabc> in <module>
#       4 # lb_view(logistic_regression(Xb, Yb), block=True)\
#       5 Xa = np.log(Xb)
# ----> 6 theta=logistic_regression(Xb, Yb)
#       7 print(theta)
#
# <ipython-input-16-906ef4ac7495> in logistic_regression(X, Y)
#       9         i += 1
#      10         prev_theta = theta
# ---> 11         grad = calc_grad(X, Y, theta)
#      12 #         print(grad)
#      13         new_theta = - (X*grad).sum(axis=0)
#
# <ipython-input-2-5c9ee26d3bfa> in calc_grad(X, Y, theta)
#       4
#       5     margins = Y * X.dot(theta)
# ----> 6     probs = 1. / (1 + np.exp(margins))
#       7     grad = -(1./m) * (X.T.dot(probs * Y))
#       8
#
# KeyboardInterrupt:

# %%
def main():
    print('==== Training model on data set A ====')
    Xa, Ya = util.load_csv('../data/ds1_a.csv', add_intercept=True)
    theta=logistic_regression(Xa, Ya)
    util.plot(Xa, Ya, theta, "po1.jpg")
    print('\n==== Training model on data set B ====')
    Xb, Yb = util.load_csv('../data/ds1_b.csv', add_intercept=True)
    theta1=logistic_regression(Xb, Yb)
    util.plot(Xb, Yb, theta1, "po2.jpg")


if __name__ == '__main__':
    main()

# %%
Xa, Ya = util.load_csv('../data/ds1_a.csv', add_intercept=False)
# util.plot_points(Xa, Ya)
x_one = Xa[Ya == -1, :]
x_two = Xa[Ya == 1, :]

plt.scatter(x_one[:,0], x_one[:,1], marker='x', color='red')
plt.scatter(x_two[:,0], x_two[:,1], marker='o', color='blue')
plt.show()
print(Xa.shape, Ya.shape)

# %%
Xb, Yb = util.load_csv('../data/ds1_b.csv', add_intercept=False)
print(Xb.shape)
# util.plot_points(Xb, Yb)
x_one = Xb[Yb == -1, :]
x_two = Xb[Yb == 1, :]

plt.scatter(x_one[:,0], x_one[:,1], marker='x', color='red')
plt.scatter(x_two[:,0], x_two[:,1], marker='o', color='blue')
plt.show()
